# %% [markdown]
# <a href="https://colab.research.google.com/github/OnesimoJr/OnesimoJr/blob/OnesimoJr-patch-1/C%C3%B3pia_de_VemtimboraWeb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Vemtimbora | Bares, Baladas e Restaurantes</title>
    <!-- ... Seu código de cabeçalho ... -->
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            background-color: #f2f2f2;
        }

        header {
            background-color: #d87710;
            color: #fff;
            text-align: center;
            padding: 10px;
        }

        .navbar {
            background-color: #333;
            overflow: hidden;
        }

        .logo {
        padding: 20px;
        border-radius: 30px; /* Arredondamento suave das bordas */

        }
        .navbar a {
            float: right;
            display: block;
            color: #fff;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
        }

        h1 {
            margin: 0;
        }

        main {
            max-width: 1200px;
            margin: 20px auto;
            padding: 20px;
            background-color: #fff;
            box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);
        }

        ul {
            list-style-type: none;
            padding: 0;
        }

        li {
            margin-bottom: 20px;
            border: 1px solid #ddd;
            padding: 10px;
            background-color: #fff;
        }

        footer {
            text-align: center;
            padding: 10px;
            background-color: #333;
            color: #fff;
        }

        .filter-container {
            display: flex;
            justify-content: space-between;
            background-color: #eee;
            padding: 10px;
            margin-bottom: 20px;
        }

        label {
            font-weight: bold;
        }

        select {
            width: 100%;
            padding: 5px;
            margin-top: 5px;
            margin-bottom: 10px;
        }
        .logo img {
            max-width: 200px; /* Ajuste o tamanho da imagem conforme necessário */
        }

        /* ... Outros estilos ... */

        .attraction-container {
            display: flex;
            flex-wrap: nowrap; /* Impede a quebra de linha das atrações */
            justify-content: space-between; /* Distribui as atrações igualmente no espaço disponível */
        }

        .attraction {
            flex: 0 0 calc(33.3333% - 20px); /* Largura fixa para cada atração (ajustável) */
            margin-right: 10px; /* Espaço entre as atrações */
            padding: 10px;
            border: 1px solid #ddd;
            background-color: #fff;
        }

        /* Estilos para a imagem, informações da atração e botão dentro de .attraction */
        .attraction img {
            max-width: 30%;
            height: center;
        }

        .attraction-info {
            text-align: center;
        }

        .join-button {
            background-color: #333;
            color: #fff;
            border: none;
            padding: 5px 10px;
            cursor: pointer;
        }
    </style>

</head>
<body>
    <header>
        <h1>Vemtimbora | Bares, Baladas e Restaurantes</h1>
    </header>
   <!-- ... Seu cabeçalho ... -->
    <div class="navbar">
        <div class="logo">
            <img src="./assets/images/Ventimbora-verde.png" alt="./assets/images/Ventimbora-verde.png"> <!-- Substitua 'seu_logo.png' pelo caminho da sua imagem -->
        </div>
        <a href="#">Login</a>
        <a href="#">Cadastre-se</a>
    </div>
    <!-- ... Sua barra de navegação ... -->
    <main>
        <div class="filter-container">
            <div>
                <label for="evento">O que tá rolando?</label>
                <select id="evento">
                    <option value="todos">Todos</option>
                    <option value="evento1">Lanchonetes</option>
                    <option value="evento2">Shows</option>
                    <option value="evento3">Bares</option>
                    <option value="evento4">Baladas</option>
                    <option value="evento5">Restaurantes</option>
                    <option value="evento6">Boates</option>
                    <option value="evento7">Raves</option>
                    <option value="evento8">Rodízios</option>
                    <option value="evento9">Teatros</option>
                    <option value="evento10">Peladas</option>
                    <!-- Adicione mais eventos conforme necessário -->
                </select>
            </div>
            <div>
                <label for="cidade">Cidades:</label>
                <select id="cidade">
                    <option value="todas">Todas as Cidades</option>
                    <option value="cidade1">Recife</option>
                    <option value="cidade2">Jaboatão</option>
                    <option value="cidade3">Olinda</option>
                    <option value="cidade4">Porto de Galinhas</option>
                    <option value="cidade5">João Pessoa</option>
                    <option value="cidade6">Maceió</option>
                    <option value="cidade7">Caruaru</option>
                    <option value="cidade8">Garanhuns</option>
                    <option value="cidade9">Paulista</option>
                    <option value="cidade10">Praia dos Carneiros</option>
                    <!-- Adicione mais cidades conforme necessário -->
                </select>
            </div>
            <div>
                <label for="categoria">Categoria:</label>
                <select id="categoria">
                    <option value="todas">Todas as Categorias</option>
                    <option value="categoria1">Localização</option>
                    <option value="categoria2">Em tempo real</option>
                    <option value="categoria3">A partir de hoje</option>
                    <option value="categoria4">Na semana</option>
                    <option value="categoria5">Este mês</option>
                    <option value="categoria6">Próximos meses</option>
                    <!-- Adicione mais categorias conforme necessário -->
                </select>
            </div>
            <div>
                <label for="periodo">Período de Realização:</label>
                <select id="periodo">
                    <option value="todos">Todos os Períodos</option>
                    <option value="periodo1">Ao vivo</option>
                    <option value="periodo2">Noite</option>
                    <option value="periodo3">Manhã</option>
                    <option value="periodo4">Tarde</option>
                    <!-- Adicione mais períodos conforme necessário -->
                </select>
            </div>
        </div>
        <!-- ... Seu conteúdo principal ... -->
        <h2>Qual é a boa???</h2>

    <ul class="attraction-list">
        <li class="attraction">
            <img src="./assets/images/bar garagem.jpeg" alt="Atração 1">
            <div class="attraction-info">
                <h3>Bar & Comedoria Garagem Alternativa</h3>
                <p>Endereço: R. Belo Oriente, 169 - Jardim Jordão, Recife - PE ⋅ Fecha às 23:00</p>
                <p>Telefone: (81) 98889-2845</p>
                <button class="join-button">Estou Dentro</button>
                <a href="https://maps.google.com/?q=Rua+Belo+Oriente+169"><button class="join-button">Localização</button></a>
                <a href="https://maps.google.com/directions"><button class="join-button">Rota</button></a>
                <a href="https://www.uber.com"><button class="join-button">Uber</button></a>
            </div>
        </li>
        <li class="attraction">
            <img src="./assets/images/parraxaxa.jpg" alt="Atração 2">
            <div class="attraction-info">
                <h3>Restaurante Parraxaxa</h3>
                <p>Endereço: Rua Fernando Simões Barbosa, 1200  - Boa Viagem, Recife - PE</p>
                <p>Telefone: (81) 3463-7874</p>
                <button class="join-button">Estou Dentro</button>
                <a href="https://maps.google.com/?q=Rua+Fernando+Simões+Barbosa%2C+1200"><button class="join-button">Localização</button></a>
                <a href="https://maps.google.com/directions"><button class="join-button">Rota</button></a>
                <a href="https://www.uber.com"><button class="join-button">Uber</button></a>
            </div>
        </li>
        <!-- Adicione mais atrações conforme necessário -->
    </ul>

    </main>
    <footer>
        <div class="footer-tabs">
            <a href="#onde-encontrar">Onde Encontrar?</a>
            <a href="#politica-privacidade">Política de Privacidade</a>
            <a href="#contato">whattsapp</a>
        </div>
        <div class="contact-info">
            <p>81 99766-8410</p>
            <p>E-mail: <a href="mailto:contato@vemtimbora.com.br">contato@vemtimbora.com.br</a></p>
        </div>
        <div class="social-buttons">
            <a href="https://www.instagram.com/vemtimbora" target="_blank"><img src="instagram.png" alt="Instagram"></a>
            <a href="https://www.facebook.com/vemtimbora" target="_blank"><img src="facebook.png" alt="Facebook"></a>
        </div>
        <div class="store-buttons">
            <a href="https://play.google.com/store/apps/vemtimbora" target="_blank"><img src="google-play.png" alt="Google Play"></a>
            <a href="https://www.apple.com/app-store/vemtimbora" target="_blank"><img src="app-store.png" alt="App Store"></a>
        </div>
    </footer>
</body>
</html>

<!-- ... continuar Código HTML daqui... -->
    <footer>
        &copy; 2023 Vemtimbora! Seu Guia de Bares e Restaurantes
    </footer>
</body>
</html>
# Out:
#   File "<tokenize>", line 135
#     <!-- ... Seu cabeçalho ... -->
#     ^
# IndentationError: unindent does not match any outer indentation level
